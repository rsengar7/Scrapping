# %%
import time, sys
import wget
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
chrome_options = Options()
chrome_options.add_argument("--start-maximized")



driver= webdriver.Chrome(options=chrome_options, executable_path='/home/ritesh/Videos/WorkBook/Imogen&Jay/Scrapping/chromedriver')

try:
    driver.get("https://www.environdec.com/library")
#     driver.get("https://level.ecomedes.com/?level-certificate.kind=1%7C2%7C3")

    
    for _ in range(1, 25000):
        time.sleep(2)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    
except Exception as e:
    print("Error :",e)
# Out:
# Error : Message: chrome not reachable
#   (Session info: chrome=102.0.5005.61)

# %%
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')



driver= webdriver.Chrome(options=chrome_options, executable_path='/home/ritesh/Videos/WorkBook/Imogen&Jay/Scrapping/chromedriver')

try:
    driver.get("https://www.environdec.com/library")
    time.sleep(4)
    
    driver.execute_script("window.scrollTo(0, 800);")
    
    
    for _ in range(1, 200):
        time.sleep(2)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    time.sleep(5)
    
    product_description = []
    registration_number = []
    status = []
    registration_date = []
    version_date = []
    valid_until = []
    geo_scope = []
    company_name = []
    country_name = []
    contact = []
    website = []
    pdf_link = []
    
    links_to_scrap = []
    
    for index in range(1, 3016):
        print()
        print()
        print()
        print("Index ------>",index)
        print('//*[@id="__next"]/main/div[1]/a[{}]'.format(index))

        data = driver.find_elements_by_xpath('//*[@id="__next"]/main/div[1]/a[{}]'.format(index))
        print(data)
        
        for i in data:
            link = i.get_attribute('href')
            print("Link : ",link)
            links_to_scrap.append(link)
        
    print("length ---->", len(links_to_scrap))
    try:
        for index, link in enumerate(links_to_scrap):
            try:
                print("Length of scraps : ",len(links_to_scrap))
                print("-------------------------",index)
                print(link)
                driver.get(link)
                product_info = driver.find_elements_by_xpath('//*[@id="__next"]/main/div[2]')
                time.sleep(1)
                for j in product_info:
                    print("Product Information : ",j.text.split("\n")[1])
                    product_description.append(j.text.split("\n")[1])

                print("*"*50)
                detail_info = driver.find_elements_by_xpath('//*[@id="__next"]/main/div[3]')

                time.sleep(1)
                for k in detail_info:
                    print(k.text)
                    _info = k.text.split("\n")
                    print(":"*100)
                    try:
                        print("Registration Number : ",_info[2])
                        registration_number.append(_info[2])
                    except:
                        registration_number.append("")
                    try:
                        print("Status : ",_info[4])
                        status.append(_info[4])
                    except:
                        status.append("")
                    try:
                        print("Registration date : ",_info[6])
                        registration_date.append(_info[6])
                    except:
                        registration_date.append("")
                    try:
                        print("Version date : ",_info[8])
                        version_date.append(_info[8])
                    except:
                        version_date.append("")
                    try:
                        print("Valid until : ",_info[10])
                        valid_until.append(_info[10])
                    except:
                        valid_until.append("")
                    try:
                        print("Geographical scopes : ",_info[12])
                        geo_scope.append(_info[12])
                    except:
                        geo_scope.append("")
                    try:
                        print("Company Name : ",_info[15])
                        company_name.append(_info[15])
                    except:
                        company_name.append("")
                    try:
                        print("Country : ",_info[17])
                        country_name.append(_info[17])
                    except:
                        country_name.append("")
                    try:
                        print("Contact : ",_info[19])
                        contact.append(_info[19])
                    except:
                        contact.append("")
                    try:
                        print("Website : ",_info[21])
                        website.append(_info[21])
                    except:
                        website.append("")
                print("/"*100)

                download = driver.find_elements_by_xpath('//*[@id="__next"]/main/div[4]/div[1]/a')
                time.sleep(1)
                for x in download:
                    try:
                        print("Pdf Name : ",x.text)
                        link = x.get_attribute('href')
                        print("Pdf link : ",link)
                        pdf_link.append(link)
                        if 'pdf' in x.text:
                            wget.download(link, "Pdf/"+str(x.text))
                        else:
                            wget.download(link, "Pdf/"+str(x.text)+".pdf")
                    except:
                        pdf_line.append("")
            except Exception as e:
                print("Error while searching detail : ",e)
    except Exception as e:
        print("Error in extraction : ",e)
        
    dict1 = {
    "Product Description": product_description,
    "Registration Number": registration_number,
    "Status": status,
    "Registration Date": registration_date,
    "Version Date": version_date,
    "Valid Until": valid_until,
    "Geographical Scope": geo_scope,
    "Company Name": company_name,
    "Country Name": country_name,
    "Contact": contact,
    "Website": website,
    "Pdf": pdf_link
    }
    
    df = pd.DataFrame(dict1)
    
    print(df.head())
    df.to_csv("level_ecomedes.csv")
    
    driver.close()
    
except Exception as e:
    print("Error :",e)
    
    driver.close()
# Out:
# Index ------> 1
# //*[@id="__next"]/main/div[1]/a[1]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="5524d013-0a54-4b18-a4c3-bb85c68e0c10")>]
# Link :  https://www.environdec.com/library/epd5973
#
#
#
# Index ------> 2
# //*[@id="__next"]/main/div[1]/a[2]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dc7a1c3d-003d-4581-8aad-bf5367045cb4")>]
# Link :  https://www.environdec.com/library/epd4739
#
#
#
# Index ------> 3
# //*[@id="__next"]/main/div[1]/a[3]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="cb9c595a-ad45-449d-acbe-0d98dff2e0b7")>]
# Link :  https://www.environdec.com/library/epd2395
#
#
#
# Index ------> 4
# //*[@id="__next"]/main/div[1]/a[4]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e9ef3772-884b-4f28-80ef-a381c8a2edc8")>]
# Link :  https://www.environdec.com/library/epd2393
#
#
#
# Index ------> 5
# //*[@id="__next"]/main/div[1]/a[5]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4a482acb-556c-4eaf-8a99-a0883e61a6ee")>]
# Link :  https://www.environdec.com/library/epd2392
#
#
#
# Index ------> 6
# //*[@id="__next"]/main/div[1]/a[6]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e228226e-5aff-4722-9794-f4b7d69870bd")>]
# Link :  https://www.environdec.com/library/epd4623
#
#
#
# Index ------> 7
# //*[@id="__next"]/main/div[1]/a[7]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="eec741b9-a4c0-4a82-a698-2a0bb5b7a85c")>]
# Link :  https://www.environdec.com/library/epd5841
#
#
#
# Index ------> 8
# //*[@id="__next"]/main/div[1]/a[8]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="98e21f61-a86c-45dd-854a-a53cf31afbdd")>]
# Link :  https://www.environdec.com/library/epd5842
#
#
#
# Index ------> 9
# //*[@id="__next"]/main/div[1]/a[9]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e9d88162-fda5-4b44-9945-557887a68adf")>]
# Link :  https://www.environdec.com/library/epd5844
#
#
#
# Index ------> 10
# //*[@id="__next"]/main/div[1]/a[10]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="85954cde-5509-4f07-8279-8d84dae5e363")>]
# Link :  https://www.environdec.com/library/epd5204
#
#
#
# Index ------> 11
# //*[@id="__next"]/main/div[1]/a[11]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="539150a7-7aab-4e19-a0df-0e57d259ac21")>]
# Link :  https://www.environdec.com/library/epd3062
#
#
#
# Index ------> 12
# //*[@id="__next"]/main/div[1]/a[12]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2dafbf82-ce1f-416b-a346-32969ac3e066")>]
# Link :  https://www.environdec.com/library/epd3063
#
#
#
# Index ------> 13
# //*[@id="__next"]/main/div[1]/a[13]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2bc6a0bf-3297-4ad2-93ff-e71bebfadddb")>]
# Link :  https://www.environdec.com/library/epd3723
#
#
#
# Index ------> 14
# //*[@id="__next"]/main/div[1]/a[14]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4a829b64-66cd-4478-a48a-ed051f1e4e25")>]
# Link :  https://www.environdec.com/library/epd6257
#
#
#
# Index ------> 15
# //*[@id="__next"]/main/div[1]/a[15]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7984f2db-8ae1-40c7-baff-a13cab38deca")>]
# Link :  https://www.environdec.com/library/epd3677
#
#
#
# Index ------> 16
# //*[@id="__next"]/main/div[1]/a[16]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="901df584-b6e9-4c70-9762-3429bf2c69d0")>]
# Link :  https://www.environdec.com/library/epd6227
#
#
#
# Index ------> 17
# //*[@id="__next"]/main/div[1]/a[17]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f6fddcdf-1ac5-43b8-891e-4bf92398e016")>]
# Link :  https://www.environdec.com/library/epd5993
#
#
#
# Index ------> 18
# //*[@id="__next"]/main/div[1]/a[18]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="0e83cb8f-0c53-48f6-8fdd-50d463ebd608")>]
# Link :  https://www.environdec.com/library/epd5893
#
#
#
# Index ------> 19
# //*[@id="__next"]/main/div[1]/a[19]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="425c5072-4e04-4899-a3fb-162e89f17ae7")>]
# Link :  https://www.environdec.com/library/epd5892
#
#
#
# Index ------> 20
# //*[@id="__next"]/main/div[1]/a[20]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="451f7f43-2852-4799-945e-2333de01e1c7")>]
# Link :  https://www.environdec.com/library/epd5891
#
#
#
# Index ------> 21
# //*[@id="__next"]/main/div[1]/a[21]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2563f3da-ad31-4120-9ebf-2ef7d53800f3")>]
# Link :  https://www.environdec.com/library/epd5890
#
#
#
# Index ------> 22
# //*[@id="__next"]/main/div[1]/a[22]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4cf7540e-2ed4-487f-a6a4-9f4572af54f6")>]
# Link :  https://www.environdec.com/library/epd5889
#
#
#
# Index ------> 23
# //*[@id="__next"]/main/div[1]/a[23]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="0fa130c2-8a30-45ae-b4c0-4956ad686b5a")>]
# Link :  https://www.environdec.com/library/epd5888
#
#
#
# Index ------> 24
# //*[@id="__next"]/main/div[1]/a[24]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="9937b248-c630-40d0-b8b3-a2054698b330")>]
# Link :  https://www.environdec.com/library/epd5887
#
#
#
# Index ------> 25
# //*[@id="__next"]/main/div[1]/a[25]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="a4dd7420-ff5b-4e2d-bc38-e64696b6eca8")>]
# Link :  https://www.environdec.com/library/epd6240
#
#
#
# Index ------> 26
# //*[@id="__next"]/main/div[1]/a[26]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="39000f83-f476-423e-92d8-7b0dfa52371c")>]
# Link :  https://www.environdec.com/library/epd4126
#
#
#
# Index ------> 27
# //*[@id="__next"]/main/div[1]/a[27]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="718b5dfd-a4ee-441e-9c02-f75ab7d81733")>]
# Link :  https://www.environdec.com/library/epd4127
#
#
#
# Index ------> 28
# //*[@id="__next"]/main/div[1]/a[28]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="b1292f52-7c6f-430f-a6f3-f8ea644863ea")>]
# Link :  https://www.environdec.com/library/epd4128
#
#
#
# Index ------> 29
# //*[@id="__next"]/main/div[1]/a[29]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dbf99ae3-75fd-4c31-a957-51dd2633c1d7")>]
# Link :  https://www.environdec.com/library/epd6082
#
#
#
# Index ------> 30
# //*[@id="__next"]/main/div[1]/a[30]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="6222ba2d-286a-4609-b4ac-efd7a0c5e9ec")>]
# Link :  https://www.environdec.com/library/epd6081
#
#
#
# Index ------> 31
# //*[@id="__next"]/main/div[1]/a[31]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="d8557aed-4853-44b3-95e4-a7c884dd75c8")>]
# Link :  https://www.environdec.com/library/epd6080
#
#
#
# Index ------> 32
# //*[@id="__next"]/main/div[1]/a[32]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7247e9aa-bb21-4dde-be9e-00509e28c397")>]
# Link :  https://www.environdec.com/library/epd6076
#
#
#
# Index ------> 33
# //*[@id="__next"]/main/div[1]/a[33]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7de51262-6eee-42af-9d49-9c077f6184ae")>]
# Link :  https://www.environdec.com/library/epd2265
#
#
#
# Index ------> 34
# //*[@id="__next"]/main/div[1]/a[34]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="430d143d-8bbb-4992-af79-ffa3277f5db4")>]
# Link :  https://www.environdec.com/library/epd6220
#
#
#
# Index ------> 35
# //*[@id="__next"]/main/div[1]/a[35]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="cb2f086c-d390-41f5-8d46-f296efa76925")>]
# Link :  https://www.environdec.com/library/epd3829
#
#
#
# Index ------> 36
# //*[@id="__next"]/main/div[1]/a[36]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="db40222a-c07f-4289-8983-d266c68ab45d")>]
# Link :  https://www.environdec.com/library/epd6225
#
#
#
# Index ------> 37
# //*[@id="__next"]/main/div[1]/a[37]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="48a586aa-ed23-41a2-9f07-2c10d20575ac")>]
# Link :  https://www.environdec.com/library/epd6229
#
#
#
# Index ------> 38
# //*[@id="__next"]/main/div[1]/a[38]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="97d3ca18-00ce-4f13-aea4-c8f3fa06b64d")>]
# Link :  https://www.environdec.com/library/epd5709
#
#
#
# Index ------> 39
# //*[@id="__next"]/main/div[1]/a[39]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="cce9a99b-3ebf-4b46-99b6-ea2c9f112444")>]
# Link :  https://www.environdec.com/library/epd5910
#
#
#
# Index ------> 40
# //*[@id="__next"]/main/div[1]/a[40]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8f28a20f-ce5c-4de4-bf8f-d8648041fa58")>]
# Link :  https://www.environdec.com/library/epd5909
#
#
#
# Index ------> 41
# //*[@id="__next"]/main/div[1]/a[41]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="b649d8d0-51b1-47bc-bf23-4e0240c18918")>]
# Link :  https://www.environdec.com/library/epd5908
#
#
#
# Index ------> 42
# //*[@id="__next"]/main/div[1]/a[42]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f6148446-6dca-49d8-99f2-e48960d4daf8")>]
# Link :  https://www.environdec.com/library/epd5907
#
#
#
# Index ------> 43
# //*[@id="__next"]/main/div[1]/a[43]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8cabb2e2-53e7-49ad-9a32-98c51ee70a80")>]
# Link :  https://www.environdec.com/library/epd6112
#
#
#
# Index ------> 44
# //*[@id="__next"]/main/div[1]/a[44]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="ccd6068c-238d-4cb2-870d-a32856e4f384")>]
# Link :  https://www.environdec.com/library/epd5809
#
#
#
# Index ------> 45
# //*[@id="__next"]/main/div[1]/a[45]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="39bc9aa1-35e2-466b-8d13-f2ee88e8ae13")>]
# Link :  https://www.environdec.com/library/epd6048
#
#
#
# Index ------> 46
# //*[@id="__next"]/main/div[1]/a[46]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4f30bee9-b913-49e3-a120-44141c47fdee")>]
# Link :  https://www.environdec.com/library/epd3679
#
#
#
# Index ------> 47
# //*[@id="__next"]/main/div[1]/a[47]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="27a7c274-6d56-4644-b01e-0d743c0fa17d")>]
# Link :  https://www.environdec.com/library/epd2623
#
#
#
# Index ------> 48
# //*[@id="__next"]/main/div[1]/a[48]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="34599d85-fb2d-46cb-8ee1-d254e9485d82")>]
# Link :  https://www.environdec.com/library/epd3678
#
#
#
# Index ------> 49
# //*[@id="__next"]/main/div[1]/a[49]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="90ca0c86-6c89-464f-8dec-21f001552faf")>]
# Link :  https://www.environdec.com/library/epd6079
#
#
#
# Index ------> 50
# //*[@id="__next"]/main/div[1]/a[50]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="ada6d28f-a031-41f9-bd70-d61bd423f9c3")>]
# Link :  https://www.environdec.com/library/epd5308
#
#
#
# Index ------> 51
# //*[@id="__next"]/main/div[1]/a[51]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e79193ff-662d-499e-98c6-3d66031cba3b")>]
# Link :  https://www.environdec.com/library/epd6088
#
#
#
# Index ------> 52
# //*[@id="__next"]/main/div[1]/a[52]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="683bf368-fa62-4106-8806-d88349ca5f0a")>]
# Link :  https://www.environdec.com/library/epd532
#
#
#
# Index ------> 53
# //*[@id="__next"]/main/div[1]/a[53]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="90a64a58-0e85-4222-b6ad-6a1ad6429511")>]
# Link :  https://www.environdec.com/library/epd6126
#
#
#
# Index ------> 54
# //*[@id="__next"]/main/div[1]/a[54]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="06a55704-0b8e-4eeb-8d4a-ef6887114ef2")>]
# Link :  https://www.environdec.com/library/epd6132
#
#
#
# Index ------> 55
# //*[@id="__next"]/main/div[1]/a[55]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8c0092d2-0f0b-423e-adfd-e3edf2b42c0a")>]
# Link :  https://www.environdec.com/library/epd6133
#
#
#
# Index ------> 56
# //*[@id="__next"]/main/div[1]/a[56]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="a5287910-ee81-4fb7-8cec-4fdfca2fab2e")>]
# Link :  https://www.environdec.com/library/epd6134
#
#
#
# Index ------> 57
# //*[@id="__next"]/main/div[1]/a[57]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="34d5d05a-7cd9-4dda-bbfd-9c020b6b3818")>]
# Link :  https://www.environdec.com/library/epd6135
#
#
#
# Index ------> 58
# //*[@id="__next"]/main/div[1]/a[58]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="ebaec820-8bc5-4ab3-8fa9-b809747e2cbc")>]
# Link :  https://www.environdec.com/library/epd6136
#
#
#
# Index ------> 59
# //*[@id="__next"]/main/div[1]/a[59]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e08cac24-1124-4474-bfdd-2bd1c2ea4184")>]
# Link :  https://www.environdec.com/library/epd6137
#
#
#
# Index ------> 60
# //*[@id="__next"]/main/div[1]/a[60]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="038eb91b-9248-4967-b7de-85b6ea059ebf")>]
# Link :  https://www.environdec.com/library/epd6138
#
#
#
# Index ------> 61
# //*[@id="__next"]/main/div[1]/a[61]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="86e6a24f-6323-46c8-b71f-d7dbdb2b8b04")>]
# Link :  https://www.environdec.com/library/epd6139
#
#
#
# Index ------> 62
# //*[@id="__next"]/main/div[1]/a[62]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8c4b992d-0848-4691-8b5f-eb1913f7e9df")>]
# Link :  https://www.environdec.com/library/epd6140
#
#
#
# Index ------> 63
# //*[@id="__next"]/main/div[1]/a[63]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f33feec2-d77b-46a9-b29e-817ae9f98b93")>]
# Link :  https://www.environdec.com/library/epd6141
#
#
#
# Index ------> 64
# //*[@id="__next"]/main/div[1]/a[64]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c8c25595-bd9f-4e32-b836-cbec2035ba8d")>]
# Link :  https://www.environdec.com/library/epd6142
#
#
#
# Index ------> 65
# //*[@id="__next"]/main/div[1]/a[65]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="6ae19279-aaea-4f48-898b-4a766f3427f8")>]
# Link :  https://www.environdec.com/library/epd5839
#
#
#
# Index ------> 66
# //*[@id="__next"]/main/div[1]/a[66]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4feae975-3105-4732-8a2c-f0db18b26fe5")>]
# Link :  https://www.environdec.com/library/epd6069
#
#
#
# Index ------> 67
# //*[@id="__next"]/main/div[1]/a[67]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="825d94bd-b075-4b40-9490-48be26ddcd2b")>]
# Link :  https://www.environdec.com/library/epd5886
#
#
#
# Index ------> 68
# //*[@id="__next"]/main/div[1]/a[68]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="257d45ce-3578-430e-a8cf-889cec1eac48")>]
# Link :  https://www.environdec.com/library/epd6067
#
#
#
# Index ------> 69
# //*[@id="__next"]/main/div[1]/a[69]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dfc9b491-4fcd-4cd5-b86f-6961387d5764")>]
# Link :  https://www.environdec.com/library/epd6066
#
#
#
# Index ------> 70
# //*[@id="__next"]/main/div[1]/a[70]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f6ffe2e7-ae21-4d11-8e46-437f99668921")>]
# Link :  https://www.environdec.com/library/epd6004
#
#
#
# Index ------> 71
# //*[@id="__next"]/main/div[1]/a[71]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="90eb2c06-c2d4-4838-8245-46ec7ecc98a5")>]
# Link :  https://www.environdec.com/library/epd3332
#
#
#
# Index ------> 72
# //*[@id="__next"]/main/div[1]/a[72]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="04e5c285-90af-4ca4-8832-8839e0f393b6")>]
# Link :  https://www.environdec.com/library/epd6065
#
#
#
# Index ------> 73
# //*[@id="__next"]/main/div[1]/a[73]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="14d217b7-9c11-4f2e-92af-4978088ae167")>]
# Link :  https://www.environdec.com/library/epd6070
#
#
#
# Index ------> 74
# //*[@id="__next"]/main/div[1]/a[74]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="edbabe1d-0518-4f5b-8a97-76fc9c758a9a")>]
# Link :  https://www.environdec.com/library/epd6129
#
#
#
# Index ------> 75
# //*[@id="__next"]/main/div[1]/a[75]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="6de63045-c8eb-4364-9eaa-fb62b8206c54")>]
# Link :  https://www.environdec.com/library/epd5631
#
#
#
# Index ------> 76
# //*[@id="__next"]/main/div[1]/a[76]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="54d10e50-6704-4fc3-a2e7-b6ec2749618a")>]
# Link :  https://www.environdec.com/library/epd5582
#
#
#
# Index ------> 77
# //*[@id="__next"]/main/div[1]/a[77]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="bfd231d5-57b6-4532-92bc-6f3e8a28c548")>]
# Link :  https://www.environdec.com/library/epd5639
#
#
#
# Index ------> 78
# //*[@id="__next"]/main/div[1]/a[78]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="942c8f4e-854b-48c9-aa27-cdc5b9d49e89")>]
# Link :  https://www.environdec.com/library/epd2032
#
#
#
# Index ------> 79
# //*[@id="__next"]/main/div[1]/a[79]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="56a95805-03c5-4432-b7aa-b85c609a955d")>]
# Link :  https://www.environdec.com/library/epd5988
#
#
#
# Index ------> 80
# //*[@id="__next"]/main/div[1]/a[80]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4ed4ecfe-8f85-4de2-b2c7-8b40db8c9fa7")>]
# Link :  https://www.environdec.com/library/epd6164
#
#
#
# Index ------> 81
# //*[@id="__next"]/main/div[1]/a[81]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="3851759d-13fb-4936-9109-4e7ad6c631cd")>]
# Link :  https://www.environdec.com/library/epd5830
#
#
#
# Index ------> 82
# //*[@id="__next"]/main/div[1]/a[82]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="35e1923c-89c9-4e02-b631-847077a2ad6f")>]
# Link :  https://www.environdec.com/library/epd5849
#
#
#
# Index ------> 83
# //*[@id="__next"]/main/div[1]/a[83]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2a882899-6fee-4686-b180-4cdef511ff8d")>]
# Link :  https://www.environdec.com/library/epd5985
#
#
#
# Index ------> 84
# //*[@id="__next"]/main/div[1]/a[84]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="555f84d1-cf51-44a0-ace3-3d7ff648a24e")>]
# Link :  https://www.environdec.com/library/epd5881
#
#
#
# Index ------> 85
# //*[@id="__next"]/main/div[1]/a[85]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="94c0df62-cb4d-42c0-aa5c-b6110fd7e900")>]
# Link :  https://www.environdec.com/library/epd5882
#
#
#
# Index ------> 86
# //*[@id="__next"]/main/div[1]/a[86]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="661049c9-a826-4300-b5b3-90182b83b4c3")>]
# Link :  https://www.environdec.com/library/epd5883
#
#
#
# Index ------> 87
# //*[@id="__next"]/main/div[1]/a[87]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f5974bb3-e772-4029-8b1b-d8446c8cb193")>]
# Link :  https://www.environdec.com/library/epd5979
#
#
#
# Index ------> 88
# //*[@id="__next"]/main/div[1]/a[88]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="943b4167-6d36-46a1-8a68-411a9b16c2fb")>]
# Link :  https://www.environdec.com/library/epd5980
#
#
#
# Index ------> 89
# //*[@id="__next"]/main/div[1]/a[89]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="93078d85-00d1-4d8e-a6d9-e1a9607d33d1")>]
# Link :  https://www.environdec.com/library/epd5981
#
#
#
# Index ------> 90
# //*[@id="__next"]/main/div[1]/a[90]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="13293fbc-6040-4609-b7f0-c80fc446dd0e")>]
# Link :  https://www.environdec.com/library/epd5982
#
#
#
# Index ------> 91
# //*[@id="__next"]/main/div[1]/a[91]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="479c1058-d8bf-436a-9fb7-b83269568433")>]
# Link :  https://www.environdec.com/library/epd5876
#
#
#
# Index ------> 92
# //*[@id="__next"]/main/div[1]/a[92]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="cef15866-c466-4354-97a9-020e957859a7")>]
# Link :  https://www.environdec.com/library/epd5874
#
#
#
# Index ------> 93
# //*[@id="__next"]/main/div[1]/a[93]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="d7d18620-949a-4f81-a7e6-dfd93706da31")>]
# Link :  https://www.environdec.com/library/epd2321
#
#
#
# Index ------> 94
# //*[@id="__next"]/main/div[1]/a[94]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="6402b146-49c7-47ab-a55e-9e64fcaebd32")>]
# Link :  https://www.environdec.com/library/epd5584
#
#
#
# Index ------> 95
# //*[@id="__next"]/main/div[1]/a[95]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="20d6eb61-41f5-4c41-8453-062ab771d4dd")>]
# Link :  https://www.environdec.com/library/epd6005
#
#
#
# Index ------> 96
# //*[@id="__next"]/main/div[1]/a[96]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="a9864bd4-d82d-4935-a3fb-f1f6a364d7f1")>]
# Link :  https://www.environdec.com/library/epd6096
#
#
#
# Index ------> 97
# //*[@id="__next"]/main/div[1]/a[97]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="6e807213-b1ec-450a-8de9-106a283cbf21")>]
# Link :  https://www.environdec.com/library/epd378
#
#
#
# Index ------> 98
# //*[@id="__next"]/main/div[1]/a[98]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="af5124b4-4fd5-47e3-9e4d-115caab301c2")>]
# Link :  https://www.environdec.com/library/epd5710
#
#
#
# Index ------> 99
# //*[@id="__next"]/main/div[1]/a[99]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="14497e15-a28d-482f-91d6-d5064cd64313")>]
# Link :  https://www.environdec.com/library/epd5711
#
#
#
# Index ------> 100
# //*[@id="__next"]/main/div[1]/a[100]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e04fa8c8-918a-48a5-8cbb-97b7db6309a4")>]
# Link :  https://www.environdec.com/library/epd5712
#
#
#
# Index ------> 101
# //*[@id="__next"]/main/div[1]/a[101]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="65cfedd9-2e43-4993-ac73-be94046621e9")>]
# Link :  https://www.environdec.com/library/epd5713
#
#
#
# Index ------> 102
# //*[@id="__next"]/main/div[1]/a[102]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c7f36f2a-2105-4840-a9a9-8e533dbebe40")>]
# Link :  https://www.environdec.com/library/epd6040
#
#
#
# Index ------> 103
# //*[@id="__next"]/main/div[1]/a[103]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="528d2834-ac21-46c8-a863-02e307b27717")>]
# Link :  https://www.environdec.com/library/epd5555
#
#
#
# Index ------> 104
# //*[@id="__next"]/main/div[1]/a[104]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="28c4c7e1-3422-413b-92a8-2311d5bcee39")>]
# Link :  https://www.environdec.com/library/epd5901
#
#
#
# Index ------> 105
# //*[@id="__next"]/main/div[1]/a[105]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="46ca920a-6690-4582-8516-0dc440f1d7b6")>]
# Link :  https://www.environdec.com/library/epd5407
#
#
#
# Index ------> 106
# //*[@id="__next"]/main/div[1]/a[106]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="25e496d5-e0ff-463e-a90a-cc14180b8f4c")>]
# Link :  https://www.environdec.com/library/epd5377
#
#
#
# Index ------> 107
# //*[@id="__next"]/main/div[1]/a[107]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8be3ceaa-3155-40e9-875c-95d48c06bc8e")>]
# Link :  https://www.environdec.com/library/epd5338
#
#
#
# Index ------> 108
# //*[@id="__next"]/main/div[1]/a[108]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7f062904-af73-4959-83d7-fdd3aabefda9")>]
# Link :  https://www.environdec.com/library/epd5336
#
#
#
# Index ------> 109
# //*[@id="__next"]/main/div[1]/a[109]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="96ac087a-0584-4d2d-b52c-f23ec7028334")>]
# Link :  https://www.environdec.com/library/epd5335
#
#
#
# Index ------> 110
# //*[@id="__next"]/main/div[1]/a[110]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="47cd4fb8-8cb1-4719-a330-1a7bd2244494")>]
# Link :  https://www.environdec.com/library/epd5337
#
#
#
# Index ------> 111
# //*[@id="__next"]/main/div[1]/a[111]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="be5cd269-9f0b-4c59-95eb-54d4bf304c06")>]
# Link :  https://www.environdec.com/library/epd5339
#
#
#
# Index ------> 112
# //*[@id="__next"]/main/div[1]/a[112]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c728a21e-da2c-424a-9a4b-bf6a573776b8")>]
# Link :  https://www.environdec.com/library/epd4933
#
#
#
# Index ------> 113
# //*[@id="__next"]/main/div[1]/a[113]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="1010f100-07ce-4802-afbb-c2babd34718b")>]
# Link :  https://www.environdec.com/library/epd5588
#
#
#
# Index ------> 114
# //*[@id="__next"]/main/div[1]/a[114]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="9cd1dcf6-f475-491c-9705-61f356e659c6")>]
# Link :  https://www.environdec.com/library/epd6050
#
#
#
# Index ------> 115
# //*[@id="__next"]/main/div[1]/a[115]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="853e2de9-a092-40b9-abb2-8195e53d474c")>]
# Link :  https://www.environdec.com/library/epd4373
#
#
#
# Index ------> 116
# //*[@id="__next"]/main/div[1]/a[116]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="88486bc6-9cc9-4de3-92ce-be71ca005578")>]
# Link :  https://www.environdec.com/library/epd4273
#
#
#
# Index ------> 117
# //*[@id="__next"]/main/div[1]/a[117]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="d46d84c5-6508-4dea-911a-7d428a15f217")>]
# Link :  https://www.environdec.com/library/epd447
#
#
#
# Index ------> 118
# //*[@id="__next"]/main/div[1]/a[118]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c37834e6-4abf-46a1-8a25-c8cf246eb1d3")>]
# Link :  https://www.environdec.com/library/epd445
#
#
#
# Index ------> 119
# //*[@id="__next"]/main/div[1]/a[119]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2bfb68fc-4f8f-41c3-9f0a-f5059c8be81f")>]
# Link :  https://www.environdec.com/library/epd446
#
#
#
# Index ------> 120
# //*[@id="__next"]/main/div[1]/a[120]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dbcc2fbb-049e-4372-9b99-2731a84975f5")>]
# Link :  https://www.environdec.com/library/epd376
#
#
#
# Index ------> 121
# //*[@id="__next"]/main/div[1]/a[121]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4d905a9e-f482-462c-b696-7ba413c22be6")>]
# Link :  https://www.environdec.com/library/epd5854
#
#
#
# Index ------> 122
# //*[@id="__next"]/main/div[1]/a[122]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2e12fe10-9219-4c2d-ad04-878b7714c946")>]
# Link :  https://www.environdec.com/library/epd5384
#
#
#
# Index ------> 123
# //*[@id="__next"]/main/div[1]/a[123]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="ef70a591-566d-4270-8528-c53a309b767c")>]
# Link :  https://www.environdec.com/library/epd5383
#
#
#
# Index ------> 124
# //*[@id="__next"]/main/div[1]/a[124]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="48bcf980-820a-49a4-a741-03dd56217635")>]
# Link :  https://www.environdec.com/library/epd5382
#
#
#
# Index ------> 125
# //*[@id="__next"]/main/div[1]/a[125]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="db9a7c37-0221-43df-8a08-42f01250070a")>]
# Link :  https://www.environdec.com/library/epd5381
#
#
#
# Index ------> 126
# //*[@id="__next"]/main/div[1]/a[126]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c4fa385b-d800-4670-89f9-6bbe3fe6cafa")>]
# Link :  https://www.environdec.com/library/epd5380
#
#
#
# Index ------> 127
# //*[@id="__next"]/main/div[1]/a[127]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="347d91d6-f69e-4b64-8db5-32a6768d553b")>]
# Link :  https://www.environdec.com/library/epd6038
#
#
#
# Index ------> 128
# //*[@id="__next"]/main/div[1]/a[128]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2283d1bf-96b6-47ed-be0f-7cbb45b3d195")>]
# Link :  https://www.environdec.com/library/epd5273
#
#
#
# Index ------> 129
# //*[@id="__next"]/main/div[1]/a[129]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c5e367a5-cf38-42e7-803c-c9ee92e75a6b")>]
# Link :  https://www.environdec.com/library/epd5274
#
#
#
# Index ------> 130
# //*[@id="__next"]/main/div[1]/a[130]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="098cdef1-b1c0-42ba-a2a3-307e08cd2405")>]
# Link :  https://www.environdec.com/library/epd5275
#
#
#
# Index ------> 131
# //*[@id="__next"]/main/div[1]/a[131]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="9c3bce2b-20e5-43da-b6c4-efd09d99ec38")>]
# Link :  https://www.environdec.com/library/epd5276
#
#
#
# Index ------> 132
# //*[@id="__next"]/main/div[1]/a[132]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="a31d74c3-104f-44d8-bce3-8699a5d6aa17")>]
# Link :  https://www.environdec.com/library/epd5277
#
#
#
# Index ------> 133
# //*[@id="__next"]/main/div[1]/a[133]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="98481ba2-0b6a-4da2-957a-436384d6835c")>]
# Link :  https://www.environdec.com/library/epd5278
#
#
#
# Index ------> 134
# //*[@id="__next"]/main/div[1]/a[134]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="fe2caca8-b374-4b28-a195-fb43d1052cce")>]
# Link :  https://www.environdec.com/library/epd4295
#
#
#
# Index ------> 135
# //*[@id="__next"]/main/div[1]/a[135]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="2aa38c95-35e3-4804-9d7b-30ce5f56048f")>]
# Link :  https://www.environdec.com/library/epd6039
#
#
#
# Index ------> 136
# //*[@id="__next"]/main/div[1]/a[136]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="aa92df78-3186-4a49-8a5e-9bbc42abd4fc")>]
# Link :  https://www.environdec.com/library/epd5698
#
#
#
# Index ------> 137
# //*[@id="__next"]/main/div[1]/a[137]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="de8f99b3-72d0-46c7-911d-1e025985cfb7")>]
# Link :  https://www.environdec.com/library/epd2112
#
#
#
# Index ------> 138
# //*[@id="__next"]/main/div[1]/a[138]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="5c25cd37-6e60-4b36-9f4b-f8b5e2e36e27")>]
# Link :  https://www.environdec.com/library/epd6053
#
#
#
# Index ------> 139
# //*[@id="__next"]/main/div[1]/a[139]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="46dc54a4-f250-4189-ac78-4b3efedbaedd")>]
# Link :  https://www.environdec.com/library/epd4661
#
#
#
# Index ------> 140
# //*[@id="__next"]/main/div[1]/a[140]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="d6e89e1d-1ecf-4269-83e3-bd6bbf1fa584")>]
# Link :  https://www.environdec.com/library/epd1005
#
#
#
# Index ------> 141
# //*[@id="__next"]/main/div[1]/a[141]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="84b72942-9bc2-4d07-bcc9-8e9151358cf8")>]
# Link :  https://www.environdec.com/library/epd5185
#
#
#
# Index ------> 142
# //*[@id="__next"]/main/div[1]/a[142]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="3b055be5-2083-42a9-86b8-c410d1eec87a")>]
# Link :  https://www.environdec.com/library/epd5727
#
#
#
# Index ------> 143
# //*[@id="__next"]/main/div[1]/a[143]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="34656678-a17f-4b48-8298-7f5077515cb6")>]
# Link :  https://www.environdec.com/library/epd6011
#
#
#
# Index ------> 144
# //*[@id="__next"]/main/div[1]/a[144]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dbe4bcae-4841-4fb7-adbf-0f346481f506")>]
# Link :  https://www.environdec.com/library/epd5754
#
#
#
# Index ------> 145
# //*[@id="__next"]/main/div[1]/a[145]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="387596d5-1e05-4c47-94db-db4c6ca4d4dd")>]
# Link :  https://www.environdec.com/library/epd6037
#
#
#
# Index ------> 146
# //*[@id="__next"]/main/div[1]/a[146]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8fefd38c-1b9c-45fb-90c9-e3a7c5c9a949")>]
# Link :  https://www.environdec.com/library/epd934
#
#
#
# Index ------> 147
# //*[@id="__next"]/main/div[1]/a[147]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7bf8c351-a3d1-4e6a-b453-f8cb8018c266")>]
# Link :  https://www.environdec.com/library/epd933
#
#
#
# Index ------> 148
# //*[@id="__next"]/main/div[1]/a[148]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="b7d9155a-b2c8-4123-a602-ca417997a0e8")>]
# Link :  https://www.environdec.com/library/epd932
#
#
#
# Index ------> 149
# //*[@id="__next"]/main/div[1]/a[149]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="5ef30617-fbc9-47b4-87e5-c2876368e76a")>]
# Link :  https://www.environdec.com/library/epd6002
#
#
#
# Index ------> 150
# //*[@id="__next"]/main/div[1]/a[150]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="057904a5-9820-42dc-a608-8be88e4ee423")>]
# Link :  https://www.environdec.com/library/epd3448
#
#
#
# Index ------> 151
# //*[@id="__next"]/main/div[1]/a[151]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="1c36c515-3aba-4e28-bd88-14c08d818dcf")>]
# Link :  https://www.environdec.com/library/epd5541
#
#
#
# Index ------> 152
# //*[@id="__next"]/main/div[1]/a[152]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="58c3f535-48c0-4879-851d-045ed1d7f97e")>]
# Link :  https://www.environdec.com/library/epd5542
#
#
#
# Index ------> 153
# //*[@id="__next"]/main/div[1]/a[153]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8b290fbd-8217-4770-b675-032eb1c271d9")>]
# Link :  https://www.environdec.com/library/epd5543
#
#
#
# Index ------> 154
# //*[@id="__next"]/main/div[1]/a[154]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8368f004-17a7-4f67-8668-fb303d486cbd")>]
# Link :  https://www.environdec.com/library/epd5815
#
#
#
# Index ------> 155
# //*[@id="__next"]/main/div[1]/a[155]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="3bf2489b-b8cb-4fc5-af1e-8a7ee28a88d3")>]
# Link :  https://www.environdec.com/library/epd5816
#
#
#
# Index ------> 156
# //*[@id="__next"]/main/div[1]/a[156]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e31efe2e-0568-4da8-ac6a-7ad5853116bc")>]
# Link :  https://www.environdec.com/library/epd2763
#
#
#
# Index ------> 157
# //*[@id="__next"]/main/div[1]/a[157]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="73c53fec-b995-42c6-af41-48b7835f8134")>]
# Link :  https://www.environdec.com/library/epd2883
#
#
#
# Index ------> 158
# //*[@id="__next"]/main/div[1]/a[158]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="56d2abdd-862b-4346-b2fc-9429731e097d")>]
# Link :  https://www.environdec.com/library/epd4024
#
#
#
# Index ------> 159
# //*[@id="__next"]/main/div[1]/a[159]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="b98696a8-48a1-400e-8fc3-fae6ce2d2d36")>]
# Link :  https://www.environdec.com/library/epd4145
#
#
#
# Index ------> 160
# //*[@id="__next"]/main/div[1]/a[160]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="89ec3a89-83a1-4d4e-ab4b-fd6838cf2e8f")>]
# Link :  https://www.environdec.com/library/epd2182
#
#
#
# Index ------> 161
# //*[@id="__next"]/main/div[1]/a[161]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="74a0dd87-a95c-46e1-a097-02ab2171d7db")>]
# Link :  https://www.environdec.com/library/epd2181
#
#
#
# Index ------> 162
# //*[@id="__next"]/main/div[1]/a[162]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="533ece69-aa5e-4f7a-9036-4318ce15f9e9")>]
# Link :  https://www.environdec.com/library/epd5266
#
#
#
# Index ------> 163
# //*[@id="__next"]/main/div[1]/a[163]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="5938c4f3-7e97-438a-8d4e-65ca31abe137")>]
# Link :  https://www.environdec.com/library/epd5865
#
#
#
# Index ------> 164
# //*[@id="__next"]/main/div[1]/a[164]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8e7050ee-dbd4-45c8-9618-f3311603d145")>]
# Link :  https://www.environdec.com/library/epd5667
#
#
#
# Index ------> 165
# //*[@id="__next"]/main/div[1]/a[165]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="74213ce8-5f28-4c1d-9719-b3d574c1bdaa")>]
# Link :  https://www.environdec.com/library/epd5870
#
#
#
# Index ------> 166
# //*[@id="__next"]/main/div[1]/a[166]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f197f283-bf24-456c-98cc-0dde22bb1d54")>]
# Link :  https://www.environdec.com/library/epd5990
#
#
#
# Index ------> 167
# //*[@id="__next"]/main/div[1]/a[167]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="af24e968-1c20-47fc-b88e-69cfcc2a0e9e")>]
# Link :  https://www.environdec.com/library/epd5717
#
#
#
# Index ------> 168
# //*[@id="__next"]/main/div[1]/a[168]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="5a096d76-388f-49a9-9447-f8bae4da211b")>]
# Link :  https://www.environdec.com/library/epd5719
#
#
#
# Index ------> 169
# //*[@id="__next"]/main/div[1]/a[169]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="c4835e51-dd34-4874-b009-acb3177d3919")>]
# Link :  https://www.environdec.com/library/epd5427
#
#
#
# Index ------> 170
# //*[@id="__next"]/main/div[1]/a[170]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="8ad120b7-d6bd-4da9-a342-e45eb03fe314")>]
# Link :  https://www.environdec.com/library/epd5574
#
#
#
# Index ------> 171
# //*[@id="__next"]/main/div[1]/a[171]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="de0e15c2-a95c-492a-bc7d-094f6c8e7df3")>]
# Link :  https://www.environdec.com/library/epd5022
#
#
#
# Index ------> 172
# //*[@id="__next"]/main/div[1]/a[172]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="b2e70778-1696-457c-8508-7c24702a6580")>]
# Link :  https://www.environdec.com/library/epd5776
#
#
#
# Index ------> 173
# //*[@id="__next"]/main/div[1]/a[173]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="d10ff733-175a-48cb-a592-f2c60179ef07")>]
# Link :  https://www.environdec.com/library/epd5725
#
#
#
# Index ------> 174
# //*[@id="__next"]/main/div[1]/a[174]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="4e5eab71-950f-449d-a164-3135275c2fc8")>]
# Link :  https://www.environdec.com/library/epd5924
#
#
#
# Index ------> 175
# //*[@id="__next"]/main/div[1]/a[175]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="278ea840-96d2-469e-b3be-15317c6c59d9")>]
# Link :  https://www.environdec.com/library/epd2989
#
#
#
# Index ------> 176
# //*[@id="__next"]/main/div[1]/a[176]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="61d0caf3-16ec-4e15-a445-3a59651592aa")>]
# Link :  https://www.environdec.com/library/epd2384
#
#
#
# Index ------> 177
# //*[@id="__next"]/main/div[1]/a[177]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="a53f2aa7-bc9c-484c-b7b7-10a3a92163e8")>]
# Link :  https://www.environdec.com/library/epd2385
#
#
#
# Index ------> 178
# //*[@id="__next"]/main/div[1]/a[178]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="f671f9b7-db2a-4a4f-8e50-0a23d092862b")>]
# Link :  https://www.environdec.com/library/epd3086
#
#
#
# Index ------> 179
# //*[@id="__next"]/main/div[1]/a[179]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="59970623-c4a9-4713-99c3-0e84bd7fd0ce")>]
# Link :  https://www.environdec.com/library/epd5906
#
#
#
# Index ------> 180
# //*[@id="__next"]/main/div[1]/a[180]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="d8569e3a-21df-4047-a61e-715190a5e842")>]
# Link :  https://www.environdec.com/library/epd5913
#
#
#
# Index ------> 181
# //*[@id="__next"]/main/div[1]/a[181]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="b6731161-fd1b-44db-a8b0-4f8860a97990")>]
# Link :  https://www.environdec.com/library/epd5914
#
#
#
# Index ------> 182
# //*[@id="__next"]/main/div[1]/a[182]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="535ec6d5-ac3d-4634-ada1-459c91f8e6f7")>]
# Link :  https://www.environdec.com/library/epd5915
#
#
#
# Index ------> 183
# //*[@id="__next"]/main/div[1]/a[183]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="91adb095-61ba-48f3-8662-a70c503a5180")>]
# Link :  https://www.environdec.com/library/epd5916
#
#
#
# Index ------> 184
# //*[@id="__next"]/main/div[1]/a[184]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="a6035b4f-7f1b-4b6e-ad6e-84da3214f68b")>]
# Link :  https://www.environdec.com/library/epd5917
#
#
#
# Index ------> 185
# //*[@id="__next"]/main/div[1]/a[185]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dc92bdb7-8bb8-4ecf-a5c8-fdb025e0ea68")>]
# Link :  https://www.environdec.com/library/epd5918
#
#
#
# Index ------> 186
# //*[@id="__next"]/main/div[1]/a[186]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7eb02c7a-ad0a-41fd-bc9e-a339efd7907c")>]
# Link :  https://www.environdec.com/library/epd5919
#
#
#
# Index ------> 187
# //*[@id="__next"]/main/div[1]/a[187]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="77695af6-9a31-4d42-91fe-e1e37ccfb049")>]
# Link :  https://www.environdec.com/library/epd5921
#
#
#
# Index ------> 188
# //*[@id="__next"]/main/div[1]/a[188]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="e08493c2-0b13-421e-8684-8edbbe17c512")>]
# Link :  https://www.environdec.com/library/epd5920
#
#
#
# Index ------> 189
# //*[@id="__next"]/main/div[1]/a[189]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="7bdf42cf-e4dc-45ce-ab45-a6bc0fc59a48")>]
# Link :  https://www.environdec.com/library/epd5623
#
#
#
# Index ------> 190
# //*[@id="__next"]/main/div[1]/a[190]
# [<selenium.webdriver.remote.webelement.WebElement (session="281b378c3d2ed76c3e701904ec91a8b5", element="dfa28938-4590-4124-8845-01b78938cc1c")>]
# ...
# Pdf Name :  S-P-005710 Hammerglass Clear single sheet 6 mm.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/16e83480-3299-4e1f-c255-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 98
# https://www.environdec.com/library/epd5711
# Product Information :  This EPD covers the version of Hammerglass Clear single sheet with 12 mm thickness with no screen printing.
# **************************************************
# Detailed information
# Registration number:
# S-P-05711
# Status:
# Registered
# Registration date:
# May 20, 2022
# Valid until:
# May 16, 2027
# Geographical scopes:
# Sweden
# Company information
# Company Name:
# Hammerglass AB
# Country:
# Sweden
# Contact:
# peter.hultberg@hammerglass.se
# Website:
# http://www.hammerglass.se
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05711
# Status :  Registered
# Registration date :  May 20, 2022
# Version date :  May 16, 2027
# Valid until :  Sweden
# Geographical scopes :  Company Name:
# Company Name :  Sweden
# Country :  peter.hultberg@hammerglass.se
# Contact :  http://www.hammerglass.se
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  S-P-005711 Hammerglass Clear single sheet 12 mm.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/fddddf04-8ff3-4252-c256-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 99
# https://www.environdec.com/library/epd5712
# Product Information :  This EPD covers the version of Hammerglass Noise barrier system GROUND-2 that is 2,3 meters high.
# **************************************************
# Detailed information
# Registration number:
# S-P-05712
# Status:
# Registered
# Registration date:
# May 20, 2022
# Valid until:
# May 16, 2027
# Geographical scopes:
# Sweden
# Company information
# Company Name:
# Hammerglass AB
# Country:
# Sweden
# Contact:
# peter.hultberg@hammerglass.se
# Website:
# http://www.hammerglass.se
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05712
# Status :  Registered
# Registration date :  May 20, 2022
# Version date :  May 16, 2027
# Valid until :  Sweden
# Geographical scopes :  Company Name:
# Company Name :  Sweden
# Country :  peter.hultberg@hammerglass.se
# Contact :  http://www.hammerglass.se
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  S-P-005712 Hammerglass Noise barrier GROUND-2.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/fcb4af30-0064-4610-c257-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 100
# https://www.environdec.com/library/epd5713
# Product Information :  This EPD covers the version of Hammerglass Noise barrier system Post free that is 2,3 meters high.
# **************************************************
# Detailed information
# Registration number:
# S-P-05713
# Status:
# Registered
# Registration date:
# May 20, 2022
# Valid until:
# May 16, 2027
# Geographical scopes:
# Sweden
# Company information
# Company Name:
# Hammerglass AB
# Country:
# Sweden
# Contact:
# peter.hultberg@hammerglass.se
# Website:
# http://www.hammerglass.se
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05713
# Status :  Registered
# Registration date :  May 20, 2022
# Version date :  May 16, 2027
# Valid until :  Sweden
# Geographical scopes :  Company Name:
# Company Name :  Sweden
# Country :  peter.hultberg@hammerglass.se
# Contact :  http://www.hammerglass.se
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  S-P-005713 Hammerglass Noise barrier Post Free.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/4a25e94b-f1c2-4141-c258-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 101
# https://www.environdec.com/library/epd6040
# Product Information :  The product is gypsum based floor screed that contains gypsum, sand and additives.
# **************************************************
# Detailed information
# Registration number:
# S-P-06040
# Status:
# Registered
# Registration date:
# May 19, 2022
# Version date:
# May 20, 2022
# Valid until:
# May 18, 2027
# Geographical scopes:
# Europe
# Company information
# Company Name:
# Fescon Oy
# Country:
# Contact:
# remy.prame@oneclicklca.com
# Website:
# www.fescon.fi
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-06040
# Status :  Registered
# Registration date :  May 19, 2022
# Version date :  May 20, 2022
# Valid until :  May 18, 2027
# Geographical scopes :  Europe
# Company Name :  Fescon Oy
# Country :  Contact:
# Contact :  Website:
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  Fescon Flow GS 3mm EPD.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/3d2c3678-a151-4616-c232-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 102
# https://www.environdec.com/library/epd5555
# Product Information :  KONE MonoSpace® 500 DX is an affordable high performance elevator solution for low-rise and mid-rise buildings. MonoSpace® 500 DX is ideal for passenger transportation in offices, hotels and residential buildings.
# **************************************************
# Detailed information
# Registration number:
# S-P-05555
# Status:
# Registered
# Registration date:
# May 20, 2022
# Valid until:
# May 19, 2027
# Geographical scopes:
# North America
# Company information
# Company Name:
# KONE Corporation
# Country:
# Finland
# Contact:
# nikunj.pokhrel@kone.com
# Website:
# https://www.kone.com/en/
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05555
# Status :  Registered
# Registration date :  May 20, 2022
# Version date :  May 19, 2027
# Valid until :  North America
# Geographical scopes :  Company Name:
# Company Name :  Finland
# Country :  nikunj.pokhrel@kone.com
# Contact :  https://www.kone.com/en/
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  KONE_MonoSpace_500_DX_ENA_EPD.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/eeb37967-e9d5-4fe2-c259-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 103
# https://www.environdec.com/library/epd5901
# Product Information :  Rigid panel, non-hydrophilic and without coating.
# **************************************************
# Detailed information
# Registration number:
# S-P-05901
# Status:
# Registered
# Registration date:
# May 20, 2022
# Valid until:
# May 19, 2027
# Geographical scopes:
# Italy
# Company information
# Company Name:
# Saint-Gobain Isover Ibérica SL
# Country:
# Spain
# Contact:
# michael.medard@saint-gobain.com
# Website:
# https://www.isover.es
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05901
# Status :  Registered
# Registration date :  May 20, 2022
# Version date :  May 19, 2027
# Valid until :  Italy
# Geographical scopes :  Company Name:
# Company Name :  Spain
# Country :  michael.medard@saint-gobain.com
# Contact :  https://www.isover.es
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  EPD Alphatoit.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/78a8d47d-09fb-4201-c271-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 104
# https://www.environdec.com/library/epd5407
# Product Information :  KONE MiniSpace™ with KONE Ultrarope® is a flexible high-quality elevator for high-rise commercial buildings and residential buildings utilizing very light carbon fiber reinforced plastic based ropes with excellent eco-efficiency, superb ride comfort and a range of design options, This compact machine-room elevator is energy- and space-efficient and come with the eco-efficient KONE EcoDisc® hoisting machine, regenerative drives, efficient lighting and advanced stand-by solutions. The components are manufactured in KONE’s manufacturing units and our suppliers in Austria, China, Czech Republic, Estonia, Finland, Germany, Italy,and Lithuania. The operation of this product are all over the world.
# **************************************************
# Detailed information
# Registration number:
# S-P-05407
# Status:
# Registered
# Registration date:
# May 3, 2022
# Version date:
# May 19, 2022
# Valid until:
# May 2, 2027
# Geographical scopes:
# Global
# Company information
# Company Name:
# KONE Corporation
# Country:
# Finland
# Contact:
# nikunj.pokhrel@kone.com
# Website:
# https://www.kone.com/en/
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05407
# Status :  Registered
# Registration date :  May 3, 2022
# Version date :  May 19, 2022
# Valid until :  May 2, 2027
# Geographical scopes :  Global
# Company Name :  KONE Corporation
# Country :  Finland
# Contact :  nikunj.pokhrel@kone.com
# Website :  https://www.kone.com/en/
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  KONE_MiniSpace_HighRise_UltraRope_EPD_revised_19.05.2022.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/eeb2da22-f557-47b5-c25b-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 105
# https://www.environdec.com/library/epd5377
# Product Information :  Merit is a hydraulic binder, mineral admixture type II, that can be used as a replacement for OPC in concrete, mortar or grout at different levels depending on national standards. Merit is also suitable for use in mass stabilisation, particularly if there is heavy metals in the soil or sludge or if there are other hazardous chemicals present.
# **************************************************
# Detailed information
# Registration number:
# S-P-05377
# Status:
# Registered
# Registration date:
# May 13, 2022
# Version date:
# May 19, 2022
# Valid until:
# May 10, 2027
# Geographical scopes:
# Sweden
# Company information
# Company Name:
# Swecem
# Country:
# Sweden
# Contact:
# madeleine.antonson@peab.se
# Website:
# https://swecem.se/
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05377
# Status :  Registered
# Registration date :  May 13, 2022
# Version date :  May 19, 2022
# Valid until :  May 10, 2027
# Geographical scopes :  Sweden
# Company Name :  Swecem
# Country :  Sweden
# Contact :  madeleine.antonson@peab.se
# Website :  https://swecem.se/
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  EPD Merit - Swecem.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/6707fea5-1338-44d8-c24c-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 106
# https://www.environdec.com/library/epd5338
# Product Information :  A double-sided glass mobile writing board with a bentwood frame. The softly rounded frame defines the work surface and doubles as a handle when moving the board between locations.
# **************************************************
# Detailed information
# Registration number:
# S-P-05338
# Status:
# Registered
# Registration date:
# May 19, 2022
# Valid until:
# May 19, 2027
# Geographical scopes:
# Global
# Company information
# Company Name:
# LINTEX AB
# Country:
# Sweden
# Contact:
# sara.gripstrand@lintex.se
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05338
# Status :  Registered
# Registration date :  May 19, 2022
# Version date :  May 19, 2027
# Valid until :  Global
# Geographical scopes :  Company Name:
# Company Name :  Sweden
# Country :  sara.gripstrand@lintex.se
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  Lintex FRAME EPD.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/a57c02d0-2593-4b07-c25f-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 107
# https://www.environdec.com/library/epd5336
# Product Information :  Moveable walls that form privacy and calm in the clutter and rush that is the modern office.
# **************************************************
# Detailed information
# Registration number:
# S-P-05336
# Status:
# Registered
# Registration date:
# May 19, 2022
# Valid until:
# May 19, 2027
# Geographical scopes:
# Global
# Company information
# Company Name:
# LINTEX AB
# Country:
# Sweden
# Contact:
# sara.gripstrand@lintex.se
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Registration Number :  S-P-05336
# Status :  Registered
# Registration date :  May 19, 2022
# Version date :  May 19, 2027
# Valid until :  Global
# Geographical scopes :  Company Name:
# Company Name :  Sweden
# Country :  sara.gripstrand@lintex.se
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# Pdf Name :  Lintex UNIT EPD.pdf
# Pdf link :  https://api.environdec.com/api/v1/EPDLibrary/Files/62f5319d-9940-40ba-c25c-08da3724454d/Data
# Length of scraps :  3015
# ------------------------- 108
# https://www.environdec.com/library/epd5335
# Error in extraction :  Message: unknown error: session deleted because of page crash
# from unknown error: cannot determine loading status
# from tab crashed
#   (Session info: chrome=102.0.5005.61)
#
# Error : arrays must all be same length
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-a63d800270ce> in <module>
#     155
# --> 156     df = pd.DataFrame(dict1)
#     157
#
# ~/Videos/venv/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#
# ~/Videos/venv/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#
# ~/Videos/venv/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#
# ~/Videos/venv/lib/python3.6/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#
# ValueError: arrays must all be same length
#
# During handling of the above exception, another exception occurred:
#
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-51-a63d800270ce> in <module>
#     164     print("Error :",e)
#     165
# --> 166     driver.close()
#
# ~/Videos/venv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# ~/Videos/venv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/Videos/venv/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSessionIdException: Message: invalid session id

# %%
chrome_options = Options()
chrome_options.add_argument("--start-maximized")



driver= webdriver.Chrome(options=chrome_options, executable_path='/home/ritesh/Videos/WorkBook/Imogen&Jay/Scrapping/chromedriver')

try:
    driver.get("https://www.environdec.com/library")
    time.sleep(4)
    driver.execute_script("window.scrollTo(0, 800);")
    time.sleep(2)
    
    data = driver.find_elements_by_xpath('//*[@id="__next"]/main/div[1]/a[1]')
    
    
#     //*[@id="__next"]/main/div[1]/a[2]
# //*[@id="__next"]/main/div[1]/a[100]

    
except Exception as e:
    print("Error :",e)

# %%
# url = "https://api.environdec.com/api/v1/EPDLibrary/Files/686e22e9-5112-47c5-b6a7-08da4d16d787/Data"
# name = "S-P-00031 Nouryon Hydrogen peroxide H2O2 (2018)"

# wget.download(url, "Pdf/"+str(name)+".pdf")
# Out:
# 'Pdf/S-P-00031 Nouryon Hydrogen peroxide H2O2 (2018).pdf'
